# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Main Heading

# %% [markdown]
# ## Sub - Heading

# %% [markdown]
# ### Heading

# %% [markdown]
# ---

# %% [markdown]
# - help me
# - save me

# %%
print("Hello sir")
# Out:
# Hello sir

# %%
a = int(input("Enter the no : "))
print(f"The square of {a} is  : {a*a}")
# Out:
# The square of 5 is  : 25
