# %%
import math

print(math.sqrt(16))
# Out:
# 4.0

# %%
from math import pi , sqrt

print(pi)

print(sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %%
import numpy as np

# %%
from math import *

print(pi)

print(sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %%
print("hello")
# Out:
# hello

# %%
# # list
# list  = ["sahil",1,True,11.2,12+1j ,"banana"]
# print(list[0:1])
# list.append("kumar")
# print(list)
# list.insert(1,0)
# print(list)
# list.remove(11.2)
# print(list)
# len(list)
# list.pop()
# print(list)
# list.append("sahil")
# list.count("sahil")
# # list.sort()
# list.index(0)
# print(list[-3:])
# for i in range(0,len(list)):
#     print(list[i])

list = [
    10,            # int
    5.7,           # float
    "Sahil",       # string
    True,          # boolean
    3+4j,          # complex
    [1,2,3],       # list
    {"name":"AI"}  # dictionary
]

print(list)
print(list[::-1])
# for num,index in enumerate(list): # in enumerate first value is index
#     print(f"Index : {num} and value : {index}")
for idx , val in enumerate(list, start=1):
    print(f"Index : {idx} and value : {val}")
# Out:
# [10, 5.7, 'Sahil', True, (3+4j), [1, 2, 3], {'name': 'AI'}]
# [{'name': 'AI'}, [1, 2, 3], (3+4j), True, 'Sahil', 5.7, 10]
# Index : 1 and value : 10
# Index : 2 and value : 5.7
# Index : 3 and value : Sahil
# Index : 4 and value : True
# Index : 5 and value : (3+4j)
# Index : 6 and value : [1, 2, 3]
# Index : 7 and value : {'name': 'AI'}

# %%
my_list = [
    10,
    5.7,
    "Sahil",
    True,
    3+4j,
    [1,2,3],
    {"name":"AI"}
]

square_1_to_10 = [i**2 for i in range(11)]
print(square_1_to_10)

names = ["sahil", "rahul", "aman"]

upper_names = [name.upper() for name in names]
print(upper_names)

s_r = [name for name in upper_names if name[0].lower() == 'r' or name[0].lower() == 's']
print(s_r)

l1 = [1,2,3]
l2 = [4,5,6]
l = [(i,j) for i in l1 for j in l2]
print(l)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# ['SAHIL', 'RAHUL', 'AMAN']
# ['SAHIL', 'RAHUL']
# [(1, 4), (1, 5), (1, 6), (2, 4), (2, 5), (2, 6), (3, 4), (3, 5), (3, 6)]

# %%
print("Hello")
